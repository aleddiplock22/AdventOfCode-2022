# %% [markdown]
# Day 9 - rope chase

# %%
insstrrc = []
with open('day9-example.txt','r') as f:
            for line in f.readlines():
                insstrrc.append(tuple(line.rstrip().split(' ')))

insstrrc
# Out:
# [('R', '4'),
#  ('U', '4'),
#  ('L', '3'),
#  ('D', '1'),
#  ('R', '4'),
#  ('D', '1'),
#  ('L', '5'),
#  ('R', '2')]

# %%
class Rope():
    def __init__(self):
        self.head_pos = [0,0]  # (x,y)-coords
        self.tail_pos = [0,0]

        self.one = [0,0]
        self.two = [0,0]
        self.three = [0,0]
        self.four = [0,0]
        self.five = [0,0]
        self.six = [0,0]
        self.seven = [0,0]
        self.eight = [0,0]

        self.instructions = []
        self.tail_previous_positions = set()
        # self.vecs = {'U':[0,1], 'D':[0,-1], 'R':[1,0], 'L':[-1,0],
        #             'UR':[1,1], 'UL':[-1,1], 'DR':[1,-1], 'DL':[-1,-1]}

    def update_instructions(self, instructions_path : str) -> list:
        instructions = []
        with open(instructions_path,'r') as f:
            for line in f.readlines():
                instructions.append(tuple(line.rstrip().split(' ')))
        self.instructions = instructions
    
    def vector_addition(self, pair1 : list, pair2 : list) -> None:
        """
        INPLACE OPERATION
        pair1 += pair2
        """
        pair1[0] += pair2[0]
        pair1[1] += pair2[1] 
        return None
    
    def sign_func(self, num):
        if num == 0:
            return 0
        if num > 0:
            return 1
        if num < 0:
            return -1


    def catch_up(self, end1=None, end2=None) -> None:
        """ 
        Move Tail appropriately if it's not close to Head.
        """
        if end1 == None: end1 = self.head_pos
        if end2 == None: end2 = self.tail_pos
    
        if self.check_proximity(end1, end2):
            return None
        else:
            # NOT WITHIN PROX!
            vec_dist = [end1[0]-end2[0], end1[1]-end2[1]] # given we check every step, this can never be more than 2,2 so halving gives us a unit vector we can move towards
            vec_catchup = [self.sign_func(vec_dist[0]),self.sign_func(vec_dist[1])]
            self.vector_addition(end2, vec_catchup)


    def check_proximity(self, end1=None, end2=None):
        if end1 == None: end1 = self.head_pos
        if end2 == None: end2 = self.tail_pos

        if (abs(end1[0] - end2[0]) > 1) or (abs(end1[1] - end2[1]) > 1):
            return False
        else:
            return True

    def one_step(self, direction : str, end):
        if direction == 'U':
            self.move_up(end)
        if direction == 'D':
            self.move_down(end)
        if direction == 'L':
            self.move_left(end)
        if direction == 'R':
            self.move_right(end)

    def move_up(self, end):
        end[1] += 1
    def move_down(self, end):
        end[1] -= 1
    def move_left(self, end):
        end[0] -= 1
    def move_right(self, end):
        end[0] += 1

    ## FULL MOVE FUNCTION HERE ###### - so do little bit at a time using one_step and catch_up ....!

    def full_move(self, direction : str, amount : int, with_updates=False):
        for _ in range(amount):
            self.tail_previous_positions.add(tuple(self.tail_pos))
            self.one_step(direction, self.head_pos)
            self.catch_up()
            self.tail_previous_positions.add(tuple(self.tail_pos))
        if with_updates: self.print_positions()
    
    ##################################################
    
    def perform_all_moves_part1(self, with_updates=False):
        self.tail_previous_positions.add(tuple(self.tail_pos))
        for instruction in self.instructions:
            tmp_direction = instruction[0]
            tmp_amount = int(instruction[1])
            self.full_move(direction=tmp_direction, amount=tmp_amount, with_updates=with_updates)


    ###### PART 2 MOVE FUNCTION ##########

    def full_move_part2(self, direction : str, amount : int, with_updates=False):
        for _ in range(amount):
            self.tail_previous_positions.add(tuple(self.tail_pos))

            self.one_step(direction, self.head_pos)

            self.catch_up(self.head_pos, self.one)
            self.catch_up(self.one, self.two)
            self.catch_up(self.two, self.three)
            self.catch_up(self.three, self.four)
            self.catch_up(self.four, self.five)
            self.catch_up(self.five, self.six)
            self.catch_up(self.six, self.seven)
            self.catch_up(self.seven, self.eight)
            self.catch_up(self.eight, self.tail_pos)

            self.tail_previous_positions.add(tuple(self.tail_pos))
        if with_updates: self.print_positions()

    def perform_all_moves_part2(self, with_updates=False):
        self.tail_previous_positions.add(tuple(self.tail_pos))
        for instruction in self.instructions:
            tmp_direction = instruction[0]
            tmp_amount = int(instruction[1])
            self.full_move_part2(direction=tmp_direction, amount=tmp_amount, with_updates=with_updates)


    def print_positions(self):
        print(f'HEAD = ({self.head_pos[0]},{self.head_pos[1]})  TAIL = ({self.tail_pos[0]},{self.tail_pos[1]})\nTail has been in {len(self.tail_previous_positions)} positions!')

# %%
rope = Rope()
rope.update_instructions('day9-example.txt')
rope.perform_all_moves_part1(with_updates=False)

# %%
big_rope = Rope()
big_rope.update_instructions('day9-input.txt')
big_rope.perform_all_moves_part1(False)
len(big_rope.tail_previous_positions)
# Out:
# 6175

# %% [markdown]
# PART 2: HOW MANY PIECES OF ROPE????

# %%
part2_rope = Rope()
part2_rope.update_instructions('day9-example2.txt')
part2_rope.perform_all_moves_part2(True)
# Out:
# HEAD = (5,0)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (5,8)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (-3,8)  TAIL = (1,3)
# Tail has been in 4 positions!
# HEAD = (-3,5)  TAIL = (1,3)
# Tail has been in 4 positions!
# HEAD = (14,5)  TAIL = (5,5)
# Tail has been in 8 positions!
# HEAD = (14,-5)  TAIL = (10,0)
# Tail has been in 13 positions!
# HEAD = (-11,-5)  TAIL = (-2,-5)
# Tail has been in 25 positions!
# HEAD = (-11,15)  TAIL = (-11,6)
# Tail has been in 36 positions!

# %%
part2_full_rope = Rope()
part2_full_rope.update_instructions('day9-input.txt')
part2_full_rope.perform_all_moves_part2(True)
# Out:
# HEAD = (0,-2)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (2,-2)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (2,0)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (2,-2)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (1,-2)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (1,-3)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (0,-3)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (0,-4)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (0,-3)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (2,-3)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (2,-1)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (2,-3)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (4,-3)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (4,-5)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (6,-5)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (6,-3)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (6,-4)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (8,-4)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (6,-4)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (8,-4)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (6,-4)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (6,-6)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (7,-6)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (7,-5)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (5,-5)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (5,-6)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (6,-6)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (6,-8)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (6,-7)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (4,-7)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (5,-7)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (5,-6)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (6,-6)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (6,-5)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (4,-5)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (4,-4)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (2,-4)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (4,-4)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (4,-3)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (4,-5)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (6,-5)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (6,-3)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (5,-3)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (6,-3)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (6,-2)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (6,-3)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (6,-2)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (6,-4)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (6,-3)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (8,-3)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (7,-3)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (7,-4)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (7,-2)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (7,-4)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (7,-3)  TAIL = (0,0)
# Tail has been in 1 positions!
# HEAD = (9,-3)  TAIL = (1,-1)
# Tail has been in 2 positions!
# HEAD = (9,-2)  TAIL = (1,-1)
# Tail has been in 2 positions!
# HEAD = (7,-2)  TAIL = (1,-1)
# Tail has been in 2 positions!
# HEAD = (9,-2)  TAIL = (1,-1)
# Tail has been in 2 positions!
# HEAD = (9,-3)  TAIL = (1,-1)
# Tail has been in 2 positions!
# HEAD = (10,-3)  TAIL = (1,-1)
# Tail has been in 2 positions!
# HEAD = (10,-2)  TAIL = (1,-1)
# Tail has been in 2 positions!
# HEAD = (10,-3)  TAIL = (1,-1)
# Tail has been in 2 positions!
# HEAD = (11,-3)  TAIL = (2,-2)
# Tail has been in 3 positions!
# HEAD = (11,-1)  TAIL = (3,-2)
# Tail has been in 4 positions!
# HEAD = (11,-3)  TAIL = (3,-2)
# Tail has been in 4 positions!
# HEAD = (13,-3)  TAIL = (4,-3)
# Tail has been in 5 positions!
# HEAD = (13,-5)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (14,-5)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (12,-5)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (12,-6)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (10,-6)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (10,-8)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (10,-6)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (10,-7)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (10,-6)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (8,-6)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (8,-4)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (10,-4)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (10,-5)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (9,-5)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (9,-7)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (8,-7)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (8,-5)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (8,-7)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (9,-7)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (9,-6)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (9,-8)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (10,-8)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (10,-7)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (12,-7)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (10,-7)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (10,-6)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (8,-6)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (9,-6)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (8,-6)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (8,-8)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (9,-8)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (9,-10)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (8,-10)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (9,-10)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (8,-10)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (8,-8)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (9,-8)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (8,-8)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (8,-6)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (8,-8)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (10,-8)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (10,-9)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (9,-9)  TAIL = (5,-4)
# Tail has been in 6 positions!
# HEAD = (9,-11)  TAIL = (6,-5)
# Tail has been in 7 positions!
# HEAD = (6,-11)  TAIL = (6,-5)
# Tail has been in 7 positions!
# HEAD = (8,-11)  TAIL = (6,-5)
# Tail has been in 7 positions!
# HEAD = (8,-9)  TAIL = (6,-5)
# Tail has been in 7 positions!
# HEAD = (9,-9)  TAIL = (6,-5)
# Tail has been in 7 positions!
# HEAD = (9,-8)  TAIL = (6,-5)
# Tail has been in 7 positions!
# HEAD = (11,-8)  TAIL = (6,-5)
# Tail has been in 7 positions!
# HEAD = (9,-8)  TAIL = (6,-5)
# Tail has been in 7 positions!
# HEAD = (9,-10)  TAIL = (6,-5)
# Tail has been in 7 positions!
# HEAD = (12,-10)  TAIL = (7,-6)
# Tail has been in 8 positions!
# HEAD = (10,-10)  TAIL = (7,-6)
# Tail has been in 8 positions!
# HEAD = (13,-10)  TAIL = (7,-6)
# Tail has been in 8 positions!
# HEAD = (13,-7)  TAIL = (7,-6)
# Tail has been in 8 positions!
# HEAD = (13,-10)  TAIL = (7,-6)
# Tail has been in 8 positions!
# HEAD = (13,-8)  TAIL = (7,-6)
# Tail has been in 8 positions!
# HEAD = (14,-8)  TAIL = (7,-6)
# Tail has been in 8 positions!
# HEAD = (14,-5)  TAIL = (7,-6)
# Tail has been in 8 positions!
# HEAD = (14,-6)  TAIL = (7,-6)
# Tail has been in 8 positions!
# HEAD = (14,-3)  TAIL = (8,-6)
# Tail has been in 9 positions!
# HEAD = (14,-4)  TAIL = (8,-6)
# Tail has been in 9 positions!
# HEAD = (14,-3)  TAIL = (8,-6)
# Tail has been in 9 positions!
# HEAD = (14,-4)  TAIL = (8,-6)
# Tail has been in 9 positions!
# HEAD = (15,-4)  TAIL = (8,-6)
# Tail has been in 9 positions!
# HEAD = (13,-4)  TAIL = (8,-6)
# Tail has been in 9 positions!
# HEAD = (13,-7)  TAIL = (8,-6)
# Tail has been in 9 positions!
# HEAD = (15,-7)  TAIL = (8,-6)
# Tail has been in 9 positions!
# HEAD = (15,-6)  TAIL = (8,-6)
# Tail has been in 9 positions!
# HEAD = (16,-6)  TAIL = (8,-6)
# Tail has been in 9 positions!
# HEAD = (16,-4)  TAIL = (8,-6)
# Tail has been in 9 positions!
# HEAD = (16,-7)  TAIL = (8,-6)
# Tail has been in 9 positions!
# HEAD = (14,-7)  TAIL = (8,-6)
# Tail has been in 9 positions!
# HEAD = (14,-9)  TAIL = (8,-6)
# Tail has been in 9 positions!
# HEAD = (15,-9)  TAIL = (8,-6)
# Tail has been in 9 positions!
# HEAD = (15,-7)  TAIL = (8,-6)
# Tail has been in 9 positions!
# HEAD = (15,-8)  TAIL = (8,-6)
# Tail has been in 9 positions!
# HEAD = (17,-8)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (14,-8)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (14,-10)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (11,-10)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (11,-8)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (13,-8)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (13,-5)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (11,-5)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (12,-5)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (12,-2)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (11,-2)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (11,-4)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (14,-4)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (14,-1)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (14,-4)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (17,-4)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (17,-7)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (14,-7)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (14,-9)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (13,-9)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (13,-8)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (15,-8)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (15,-5)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (13,-5)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (14,-5)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (12,-5)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (15,-5)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (14,-5)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (16,-5)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (15,-5)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (15,-8)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (15,-5)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (14,-5)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (17,-5)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (17,-8)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (15,-8)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (15,-7)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (15,-8)  TAIL = (9,-7)
# Tail has been in 10 positions!
# HEAD = (12,-8)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (12,-11)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (10,-11)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (10,-12)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (10,-10)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (10,-12)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (9,-12)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (9,-10)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (6,-10)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (6,-11)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (6,-10)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (9,-10)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (9,-8)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (6,-8)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (6,-5)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (4,-5)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (5,-5)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (5,-3)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (5,-4)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (8,-4)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (8,-5)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (8,-4)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (6,-4)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (6,-5)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (9,-5)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (9,-8)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (9,-6)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (9,-9)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (9,-6)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (11,-6)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (9,-6)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (12,-6)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (10,-6)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (12,-6)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (12,-9)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (14,-9)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (14,-8)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (14,-9)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (17,-9)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (17,-6)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (15,-6)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (15,-5)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (18,-5)  TAIL = (10,-6)
# Tail has been in 11 positions!
# HEAD = (18,-1)  TAIL = (12,-5)
# Tail has been in 13 positions!
# HEAD = (14,-1)  TAIL = (12,-5)
# Tail has been in 13 positions!
# HEAD = (14,-5)  TAIL = (12,-5)
# Tail has been in 13 positions!
# HEAD = (14,-3)  TAIL = (12,-5)
# Tail has been in 13 positions!
# HEAD = (12,-3)  TAIL = (12,-5)
# Tail has been in 13 positions!
# HEAD = (12,-6)  TAIL = (12,-5)
# Tail has been in 13 positions!
# HEAD = (10,-6)  TAIL = (12,-5)
# Tail has been in 13 positions!
# HEAD = (12,-6)  TAIL = (12,-5)
# Tail has been in 13 positions!
# HEAD = (8,-6)  TAIL = (12,-5)
# Tail has been in 13 positions!
# HEAD = (8,-3)  TAIL = (12,-5)
# Tail has been in 13 positions!
# HEAD = (9,-3)  TAIL = (12,-5)
# Tail has been in 13 positions!
# HEAD = (9,-1)  TAIL = (12,-5)
# Tail has been in 13 positions!
# HEAD = (13,-1)  TAIL = (12,-5)
# Tail has been in 13 positions!
# HEAD = (11,-1)  TAIL = (12,-5)
# Tail has been in 13 positions!
# HEAD = (11,2)  TAIL = (12,-5)
# Tail has been in 13 positions!
# HEAD = (14,2)  TAIL = (12,-5)
# Tail has been in 13 positions!
# HEAD = (13,2)  TAIL = (12,-5)
# Tail has been in 13 positions!
# HEAD = (14,2)  TAIL = (12,-5)
# Tail has been in 13 positions!
# HEAD = (14,6)  TAIL = (14,-3)
# Tail has been in 15 positions!
# HEAD = (12,6)  TAIL = (13,-2)
# Tail has been in 16 positions!
# HEAD = (13,6)  TAIL = (13,-2)
# Tail has been in 16 positions!
# HEAD = (13,10)  TAIL = (13,1)
# Tail has been in 19 positions!
# HEAD = (9,10)  TAIL = (11,3)
# Tail has been in 21 positions!
# HEAD = (9,11)  TAIL = (11,3)
# Tail has been in 21 positions!
# HEAD = (9,10)  TAIL = (11,3)
# Tail has been in 21 positions!
# HEAD = (9,11)  TAIL = (11,3)
# Tail has been in 21 positions!
# HEAD = (11,11)  TAIL = (11,3)
# Tail has been in 21 positions!
# HEAD = (9,11)  TAIL = (11,3)
# Tail has been in 21 positions!
# HEAD = (9,10)  TAIL = (11,3)
# Tail has been in 21 positions!
# HEAD = (9,13)  TAIL = (10,4)
# Tail has been in 22 positions!
# HEAD = (9,11)  TAIL = (10,4)
# Tail has been in 22 positions!
# HEAD = (9,15)  TAIL = (9,6)
# Tail has been in 24 positions!
# HEAD = (13,15)  TAIL = (11,8)
# Tail has been in 26 positions!
# HEAD = (11,15)  TAIL = (11,8)
# Tail has been in 26 positions!
# HEAD = (11,19)  TAIL = (11,10)
# Tail has been in 28 positions!
# HEAD = (15,19)  TAIL = (13,12)
# Tail has been in 30 positions!
# HEAD = (15,18)  TAIL = (13,12)
# Tail has been in 30 positions!
# HEAD = (16,18)  TAIL = (13,12)
# Tail has been in 30 positions!
# HEAD = (16,20)  TAIL = (14,13)
# Tail has been in 31 positions!
# HEAD = (13,20)  TAIL = (14,13)
# Tail has been in 31 positions!
# HEAD = (16,20)  TAIL = (14,13)
# Tail has been in 31 positions!
# HEAD = (16,18)  TAIL = (14,13)
# Tail has been in 31 positions!
# HEAD = (15,18)  TAIL = (14,13)
# Tail has been in 31 positions!
# HEAD = (15,22)  TAIL = (14,13)
# Tail has been in 31 positions!
# HEAD = (18,22)  TAIL = (15,14)
# Tail has been in 32 positions!
# HEAD = (18,21)  TAIL = (15,14)
# Tail has been in 32 positions!
# HEAD = (18,23)  TAIL = (15,14)
# Tail has been in 32 positions!
# HEAD = (18,20)  TAIL = (16,15)
# Tail has been in 33 positions!
# HEAD = (22,20)  TAIL = (17,16)
# Tail has been in 34 positions!
# HEAD = (22,23)  TAIL = (18,17)
# Tail has been in 35 positions!
# HEAD = (22,20)  TAIL = (18,17)
# Tail has been in 35 positions!
# HEAD = (23,20)  TAIL = (18,17)
# Tail has been in 35 positions!
# HEAD = (21,20)  TAIL = (18,17)
# Tail has been in 35 positions!
# HEAD = (21,16)  TAIL = (18,17)
# Tail has been in 35 positions!
# HEAD = (19,16)  TAIL = (18,17)
# Tail has been in 35 positions!
# HEAD = (21,16)  TAIL = (18,17)
# Tail has been in 35 positions!
# HEAD = (21,12)  TAIL = (18,17)
# Tail has been in 35 positions!
# HEAD = (21,16)  TAIL = (18,17)
# Tail has been in 35 positions!
# HEAD = (21,12)  TAIL = (18,17)
# Tail has been in 35 positions!
# HEAD = (17,12)  TAIL = (18,17)
# Tail has been in 35 positions!
# HEAD = (17,16)  TAIL = (18,17)
# Tail has been in 35 positions!
# HEAD = (17,12)  TAIL = (18,17)
# Tail has been in 35 positions!
# HEAD = (15,12)  TAIL = (18,17)
# Tail has been in 35 positions!
# HEAD = (18,12)  TAIL = (18,17)
# Tail has been in 35 positions!
# HEAD = (15,12)  TAIL = (18,17)
# Tail has been in 35 positions!
# HEAD = (18,12)  TAIL = (18,17)
# Tail has been in 35 positions!
# HEAD = (14,12)  TAIL = (18,17)
# Tail has been in 35 positions!
# HEAD = (15,12)  TAIL = (18,17)
# Tail has been in 35 positions!
# HEAD = (14,12)  TAIL = (18,17)
# Tail has been in 35 positions!
# HEAD = (14,14)  TAIL = (18,17)
# Tail has been in 35 positions!
# HEAD = (14,10)  TAIL = (18,17)
# Tail has been in 35 positions!
# HEAD = (10,10)  TAIL = (16,15)
# Tail has been in 35 positions!
# HEAD = (11,10)  TAIL = (16,15)
# Tail has been in 35 positions!
# HEAD = (11,9)  TAIL = (16,15)
# Tail has been in 35 positions!
# HEAD = (14,9)  TAIL = (16,15)
# Tail has been in 35 positions!
# HEAD = (12,9)  TAIL = (16,15)
# Tail has been in 35 positions!
# HEAD = (12,12)  TAIL = (16,15)
# Tail has been in 35 positions!
# HEAD = (16,12)  TAIL = (16,15)
# Tail has been in 35 positions!
# HEAD = (16,16)  TAIL = (16,15)
# Tail has been in 35 positions!
# HEAD = (18,16)  TAIL = (16,15)
# Tail has been in 35 positions!
# HEAD = (18,12)  TAIL = (16,15)
# Tail has been in 35 positions!
# HEAD = (21,12)  TAIL = (16,15)
# Tail has been in 35 positions!
# HEAD = (21,16)  TAIL = (16,15)
# Tail has been in 35 positions!
# HEAD = (25,16)  TAIL = (16,15)
# Tail has been in 35 positions!
# HEAD = (24,16)  TAIL = (16,15)
# Tail has been in 35 positions!
# HEAD = (24,12)  TAIL = (17,15)
# Tail has been in 36 positions!
# HEAD = (24,15)  TAIL = (17,15)
# Tail has been in 36 positions!
# HEAD = (27,15)  TAIL = (18,15)
# Tail has been in 37 positions!
# HEAD = (27,12)  TAIL = (19,14)
# Tail has been in 38 positions!
# HEAD = (27,15)  TAIL = (19,14)
# Tail has been in 38 positions!
# HEAD = (30,15)  TAIL = (21,15)
# Tail has been in 40 positions!
# HEAD = (30,18)  TAIL = (22,16)
# Tail has been in 41 positions!
# HEAD = (27,18)  TAIL = (22,16)
# Tail has been in 41 positions!
# HEAD = (27,16)  TAIL = (22,16)
# Tail has been in 41 positions!
# HEAD = (30,16)  TAIL = (22,16)
# Tail has been in 41 positions!
# HEAD = (29,16)  TAIL = (22,16)
# Tail has been in 41 positions!
# HEAD = (33,16)  TAIL = (24,16)
# Tail has been in 43 positions!
# HEAD = (33,15)  TAIL = (24,16)
# Tail has been in 43 positions!
# HEAD = (36,15)  TAIL = (27,15)
# Tail has been in 46 positions!
# HEAD = (36,11)  TAIL = (29,13)
# Tail has been in 48 positions!
# HEAD = (32,11)  TAIL = (29,13)
# Tail has been in 48 positions!
# HEAD = (32,15)  TAIL = (29,13)
# Tail has been in 48 positions!
# HEAD = (33,15)  TAIL = (29,13)
# Tail has been in 48 positions!
# HEAD = (33,12)  TAIL = (29,13)
# Tail has been in 48 positions!
# HEAD = (33,16)  TAIL = (29,13)
# Tail has been in 48 positions!
# HEAD = (34,16)  TAIL = (29,13)
# Tail has been in 48 positions!
# HEAD = (34,14)  TAIL = (29,13)
# Tail has been in 48 positions!
# HEAD = (38,14)  TAIL = (29,13)
# Tail has been in 48 positions!
# HEAD = (38,9)  TAIL = (31,12)
# Tail has been in 50 positions!
# HEAD = (38,11)  TAIL = (31,12)
# Tail has been in 50 positions!
# HEAD = (36,11)  TAIL = (31,12)
# Tail has been in 50 positions!
# HEAD = (36,14)  TAIL = (31,12)
# Tail has been in 50 positions!
# HEAD = (40,14)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (38,14)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (38,17)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (34,17)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (34,20)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (34,17)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (37,17)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (37,14)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (34,14)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (34,15)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (37,15)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (33,15)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (34,15)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (34,18)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (35,18)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (31,18)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (31,13)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (31,16)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (31,14)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (33,14)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (33,16)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (33,12)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (37,12)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (37,14)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (38,14)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (35,14)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (35,13)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (32,13)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (36,13)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (31,13)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (31,9)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (33,9)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (28,9)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (33,9)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (33,10)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (33,6)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (35,6)  TAIL = (32,13)
# Tail has been in 51 positions!
# HEAD = (35,1)  TAIL = (35,10)
# Tail has been in 54 positions!
# HEAD = (36,1)  TAIL = (35,10)
# Tail has been in 54 positions!
# HEAD = (33,1)  TAIL = (34,9)
# Tail has been in 55 positions!
# HEAD = (34,1)  TAIL = (34,9)
# Tail has been in 55 positions!
# HEAD = (34,4)  TAIL = (34,9)
# Tail has been in 55 positions!
# HEAD = (34,2)  TAIL = (34,9)
# Tail has been in 55 positions!
# HEAD = (35,2)  TAIL = (34,9)
# Tail has been in 55 positions!
# HEAD = (33,2)  TAIL = (34,9)
# Tail has been in 55 positions!
# HEAD = (34,2)  TAIL = (34,9)
# Tail has been in 55 positions!
# HEAD = (34,-3)  TAIL = (34,6)
# Tail has been in 58 positions!
# HEAD = (34,0)  TAIL = (34,6)
# Tail has been in 58 positions!
# HEAD = (31,0)  TAIL = (34,6)
# Tail has been in 58 positions!
# HEAD = (31,4)  TAIL = (34,6)
# Tail has been in 58 positions!
# HEAD = (28,4)  TAIL = (34,6)
# Tail has been in 58 positions!
# HEAD = (28,2)  TAIL = (34,6)
# Tail has been in 58 positions!
# HEAD = (24,2)  TAIL = (32,4)
# Tail has been in 60 positions!
# HEAD = (24,4)  TAIL = (32,4)
# Tail has been in 60 positions!
# HEAD = (24,0)  TAIL = (31,3)
# Tail has been in 61 positions!
# HEAD = (24,2)  TAIL = (31,3)
# Tail has been in 61 positions!
# HEAD = (20,2)  TAIL = (29,2)
# Tail has been in 63 positions!
# HEAD = (21,2)  TAIL = (29,2)
# Tail has been in 63 positions!
# HEAD = (21,1)  TAIL = (29,2)
# Tail has been in 63 positions!
# HEAD = (21,2)  TAIL = (29,2)
# Tail has been in 63 positions!
# HEAD = (21,1)  TAIL = (29,2)
# Tail has been in 63 positions!
# HEAD = (21,3)  TAIL = (29,2)
# Tail has been in 63 positions!
# HEAD = (18,3)  TAIL = (27,3)
# Tail has been in 65 positions!
# HEAD = (19,3)  TAIL = (27,3)
# Tail has been in 65 positions!
# HEAD = (19,4)  TAIL = (27,3)
# Tail has been in 65 positions!
# HEAD = (17,4)  TAIL = (26,4)
# Tail has been in 66 positions!
# HEAD = (17,2)  TAIL = (25,3)
# Tail has been in 67 positions!
# HEAD = (20,2)  TAIL = (25,3)
# Tail has been in 67 positions!
# HEAD = (17,2)  TAIL = (25,3)
# Tail has been in 67 positions!
# HEAD = (18,2)  TAIL = (25,3)
# Tail has been in 67 positions!
# HEAD = (18,6)  TAIL = (25,3)
# Tail has been in 67 positions!
# HEAD = (20,6)  TAIL = (25,3)
# Tail has been in 67 positions!
# HEAD = (19,6)  TAIL = (25,3)
# Tail has been in 67 positions!
# HEAD = (19,4)  TAIL = (25,3)
# Tail has been in 67 positions!
# HEAD = (23,4)  TAIL = (25,3)
# Tail has been in 67 positions!
# HEAD = (18,4)  TAIL = (25,3)
# Tail has been in 67 positions!
# HEAD = (18,3)  TAIL = (25,3)
# Tail has been in 67 positions!
# HEAD = (20,3)  TAIL = (25,3)
# Tail has been in 67 positions!
# HEAD = (20,4)  TAIL = (25,3)
# Tail has been in 67 positions!
# HEAD = (18,4)  TAIL = (25,3)
# Tail has been in 67 positions!
# HEAD = (18,9)  TAIL = (23,5)
# Tail has been in 69 positions!
# HEAD = (18,6)  TAIL = (23,5)
# Tail has been in 69 positions!
# HEAD = (18,9)  TAIL = (23,5)
# Tail has been in 69 positions!
# HEAD = (18,8)  TAIL = (23,5)
# Tail has been in 69 positions!
# HEAD = (18,10)  TAIL = (23,5)
# Tail has been in 69 positions!
# HEAD = (18,6)  TAIL = (23,5)
# Tail has been in 69 positions!
# HEAD = (18,7)  TAIL = (23,5)
# Tail has been in 69 positions!
# HEAD = (16,7)  TAIL = (23,5)
# Tail has been in 69 positions!
# HEAD = (20,7)  TAIL = (23,5)
# Tail has been in 69 positions!
# HEAD = (15,7)  TAIL = (23,5)
# Tail has been in 69 positions!
# HEAD = (15,11)  TAIL = (21,7)
# Tail has been in 71 positions!
# HEAD = (15,8)  TAIL = (21,7)
# Tail has been in 71 positions!
# HEAD = (15,9)  TAIL = (21,7)
# Tail has been in 71 positions!
# HEAD = (15,7)  TAIL = (21,7)
# Tail has been in 71 positions!
# HEAD = (10,7)  TAIL = (19,7)
# Tail has been in 73 positions!
# HEAD = (10,12)  TAIL = (17,9)
# Tail has been in 75 positions!
# HEAD = (10,10)  TAIL = (17,9)
# Tail has been in 75 positions!
# HEAD = (8,10)  TAIL = (17,9)
# Tail has been in 75 positions!
# HEAD = (8,8)  TAIL = (16,9)
# Tail has been in 76 positions!
# HEAD = (8,12)  TAIL = (15,10)
# Tail has been in 77 positions!
# HEAD = (13,12)  TAIL = (15,10)
# Tail has been in 77 positions!
# HEAD = (13,11)  TAIL = (15,10)
# Tail has been in 77 positions!
# HEAD = (15,11)  TAIL = (15,10)
# Tail has been in 77 positions!
# HEAD = (13,11)  TAIL = (15,10)
# Tail has been in 77 positions!
# HEAD = (13,10)  TAIL = (15,10)
# Tail has been in 77 positions!
# HEAD = (15,10)  TAIL = (15,10)
# Tail has been in 77 positions!
# HEAD = (9,10)  TAIL = (15,10)
# Tail has been in 77 positions!
# HEAD = (9,13)  TAIL = (15,10)
# Tail has been in 77 positions!
# HEAD = (10,13)  TAIL = (15,10)
# Tail has been in 77 positions!
# HEAD = (10,7)  TAIL = (15,10)
# Tail has been in 77 positions!
# HEAD = (10,8)  TAIL = (15,10)
# Tail has been in 77 positions!
# HEAD = (10,4)  TAIL = (14,9)
# Tail has been in 78 positions!
# HEAD = (16,4)  TAIL = (14,9)
# Tail has been in 78 positions!
# HEAD = (16,7)  TAIL = (14,9)
# Tail has been in 78 positions!
# HEAD = (10,7)  TAIL = (14,9)
# Tail has been in 78 positions!
# HEAD = (10,10)  TAIL = (14,9)
# Tail has been in 78 positions!
# HEAD = (8,10)  TAIL = (14,9)
# Tail has been in 78 positions!
# HEAD = (8,13)  TAIL = (14,9)
# Tail has been in 78 positions!
# HEAD = (12,13)  TAIL = (14,9)
# Tail has been in 78 positions!
# HEAD = (12,18)  TAIL = (13,10)
# Tail has been in 79 positions!
# HEAD = (12,14)  TAIL = (13,10)
# Tail has been in 79 positions!
# HEAD = (17,14)  TAIL = (13,10)
# Tail has been in 79 positions!
# HEAD = (17,8)  TAIL = (13,10)
# Tail has been in 79 positions!
# HEAD = (17,9)  TAIL = (13,10)
# Tail has been in 79 positions!
# HEAD = (19,9)  TAIL = (13,10)
# Tail has been in 79 positions!
# HEAD = (19,10)  TAIL = (13,10)
# Tail has been in 79 positions!
# HEAD = (19,5)  TAIL = (13,10)
# Tail has been in 79 positions!
# HEAD = (23,5)  TAIL = (15,8)
# Tail has been in 80 positions!
# HEAD = (20,5)  TAIL = (15,8)
# Tail has been in 80 positions!
# HEAD = (20,1)  TAIL = (16,7)
# Tail has been in 81 positions!
# HEAD = (20,6)  TAIL = (16,7)
# Tail has been in 81 positions!
# HEAD = (15,6)  TAIL = (16,7)
# Tail has been in 81 positions!
# HEAD = (15,11)  TAIL = (16,7)
# Tail has been in 81 positions!
# HEAD = (11,11)  TAIL = (16,7)
# Tail has been in 81 positions!
# HEAD = (11,12)  TAIL = (16,7)
# Tail has been in 81 positions!
# HEAD = (11,6)  TAIL = (16,7)
# Tail has been in 81 positions!
# HEAD = (17,6)  TAIL = (16,7)
# Tail has been in 81 positions!
# HEAD = (13,6)  TAIL = (16,7)
# Tail has been in 81 positions!
# HEAD = (17,6)  TAIL = (16,7)
# Tail has been in 81 positions!
# HEAD = (17,5)  TAIL = (16,7)
# Tail has been in 81 positions!
# HEAD = (18,5)  TAIL = (16,7)
# Tail has been in 81 positions!
# HEAD = (13,5)  TAIL = (16,7)
# Tail has been in 81 positions!
# HEAD = (13,7)  TAIL = (16,7)
# Tail has been in 81 positions!
# HEAD = (13,4)  TAIL = (16,7)
# Tail has been in 81 positions!
# HEAD = (13,9)  TAIL = (16,7)
# Tail has been in 81 positions!
# HEAD = (13,3)  TAIL = (16,7)
# Tail has been in 81 positions!
# HEAD = (16,3)  TAIL = (16,7)
# Tail has been in 81 positions!
# HEAD = (10,3)  TAIL = (16,7)
# Tail has been in 81 positions!
# HEAD = (10,9)  TAIL = (16,7)
# Tail has been in 81 positions!
# HEAD = (10,5)  TAIL = (16,7)
# Tail has been in 81 positions!
# HEAD = (10,9)  TAIL = (16,7)
# Tail has been in 81 positions!
# HEAD = (10,6)  TAIL = (16,7)
# Tail has been in 81 positions!
# HEAD = (5,6)  TAIL = (14,6)
# Tail has been in 83 positions!
# HEAD = (5,0)  TAIL = (11,3)
# Tail has been in 85 positions!
# HEAD = (5,5)  TAIL = (11,3)
# Tail has been in 85 positions!
# HEAD = (8,5)  TAIL = (11,3)
# Tail has been in 85 positions!
# HEAD = (8,11)  TAIL = (10,4)
# Tail has been in 85 positions!
# HEAD = (8,7)  TAIL = (10,4)
# Tail has been in 85 positions!
# HEAD = (8,8)  TAIL = (10,4)
# Tail has been in 85 positions!
# HEAD = (10,8)  TAIL = (10,4)
# Tail has been in 85 positions!
# HEAD = (10,7)  TAIL = (10,4)
# Tail has been in 85 positions!
# HEAD = (7,7)  TAIL = (10,4)
# Tail has been in 85 positions!
# HEAD = (9,7)  TAIL = (10,4)
# Tail has been in 85 positions!
# HEAD = (9,12)  TAIL = (10,4)
# Tail has been in 85 positions!
# HEAD = (11,12)  TAIL = (10,4)
# Tail has been in 85 positions!
# HEAD = (5,12)  TAIL = (8,6)
# Tail has been in 86 positions!
# HEAD = (5,9)  TAIL = (8,6)
# Tail has been in 86 positions!
# HEAD = (7,9)  TAIL = (8,6)
# Tail has been in 86 positions!
# HEAD = (7,11)  TAIL = (8,6)
# Tail has been in 86 positions!
# HEAD = (12,11)  TAIL = (8,6)
# Tail has been in 86 positions!
# HEAD = (12,17)  TAIL = (11,9)
# Tail has been in 88 positions!
# HEAD = (16,17)  TAIL = (13,11)
# Tail has been in 90 positions!
# HEAD = (16,21)  TAIL = (15,13)
# Tail has been in 92 positions!
# HEAD = (16,17)  TAIL = (15,13)
# Tail has been in 92 positions!
# HEAD = (16,19)  TAIL = (15,13)
# Tail has been in 92 positions!
# HEAD = (22,19)  TAIL = (17,15)
# Tail has been in 93 positions!
# HEAD = (22,22)  TAIL = (18,16)
# Tail has been in 94 positions!
# HEAD = (19,22)  TAIL = (18,16)
# Tail has been in 94 positions!
# HEAD = (19,21)  TAIL = (18,16)
# Tail has been in 94 positions!
# HEAD = (21,21)  TAIL = (18,16)
# Tail has been in 94 positions!
# HEAD = (16,21)  TAIL = (18,16)
# Tail has been in 94 positions!
# HEAD = (16,16)  TAIL = (18,16)
# Tail has been in 94 positions!
# HEAD = (16,22)  TAIL = (18,16)
# Tail has been in 94 positions!
# HEAD = (16,17)  TAIL = (18,16)
# Tail has been in 94 positions!
# HEAD = (17,17)  TAIL = (18,16)
# Tail has been in 94 positions!
# HEAD = (17,16)  TAIL = (18,16)
# Tail has been in 94 positions!
# HEAD = (17,22)  TAIL = (18,16)
# Tail has been in 94 positions!
# HEAD = (17,18)  TAIL = (18,16)
# Tail has been in 94 positions!
# HEAD = (20,18)  TAIL = (18,16)
# Tail has been in 94 positions!
# HEAD = (20,24)  TAIL = (18,16)
# Tail has been in 94 positions!
# HEAD = (15,24)  TAIL = (18,17)
# Tail has been in 94 positions!
# HEAD = (15,29)  TAIL = (15,20)
# Tail has been in 97 positions!
# HEAD = (15,28)  TAIL = (15,20)
# Tail has been in 97 positions!
# HEAD = (15,34)  TAIL = (15,25)
# Tail has been in 102 positions!
# HEAD = (13,34)  TAIL = (14,26)
# Tail has been in 103 positions!
# HEAD = (13,32)  TAIL = (14,26)
# Tail has been in 103 positions!
# HEAD = (13,38)  TAIL = (13,29)
# Tail has been in 106 positions!
# HEAD = (8,38)  TAIL = (11,31)
# Tail has been in 108 positions!
# HEAD = (8,44)  TAIL = (8,35)
# Tail has been in 112 positions!
# HEAD = (6,44)  TAIL = (7,36)
# Tail has been in 113 positions!
# HEAD = (6,43)  TAIL = (7,36)
# Tail has been in 113 positions!
# HEAD = (11,43)  TAIL = (8,37)
# Tail has been in 114 positions!
# HEAD = (11,47)  TAIL = (10,39)
# Tail has been in 116 positions!
# HEAD = (17,47)  TAIL = (13,42)
# Tail has been in 119 positions!
# HEAD = (17,42)  TAIL = (13,42)
# Tail has been in 119 positions!
# HEAD = (18,42)  TAIL = (13,42)
# Tail has been in 119 positions!
# HEAD = (17,42)  TAIL = (13,42)
# Tail has been in 119 positions!
# HEAD = (17,44)  TAIL = (13,42)
# Tail has been in 119 positions!
# HEAD = (16,44)  TAIL = (13,42)
# Tail has been in 119 positions!
# HEAD = (17,44)  TAIL = (13,42)
# Tail has been in 119 positions!
# HEAD = (17,38)  TAIL = (13,42)
# Tail has been in 119 positions!
# HEAD = (11,38)  TAIL = (13,42)
# Tail has been in 119 positions!
# HEAD = (15,38)  TAIL = (13,42)
# Tail has been in 119 positions!
# HEAD = (15,34)  TAIL = (13,42)
# Tail has been in 119 positions!
# HEAD = (12,34)  TAIL = (13,42)
# Tail has been in 119 positions!
# HEAD = (12,33)  TAIL = (13,42)
# Tail has been in 119 positions!
# HEAD = (12,35)  TAIL = (13,42)
# Tail has been in 119 positions!
# HEAD = (9,35)  TAIL = (13,41)
# Tail has been in 120 positions!
# HEAD = (13,35)  TAIL = (13,41)
# Tail has been in 120 positions!
# HEAD = (13,29)  TAIL = (13,38)
# Tail has been in 123 positions!
# HEAD = (13,34)  TAIL = (13,38)
# Tail has been in 123 positions!
# HEAD = (13,31)  TAIL = (13,38)
# Tail has been in 123 positions!
# HEAD = (9,31)  TAIL = (12,37)
# Tail has been in 124 positions!
# HEAD = (15,31)  TAIL = (12,37)
# Tail has been in 124 positions!
# HEAD = (8,31)  TAIL = (12,37)
# Tail has been in 124 positions!
# HEAD = (8,35)  TAIL = (12,37)
# Tail has been in 124 positions!
# HEAD = (12,35)  TAIL = (12,37)
# Tail has been in 124 positions!
# HEAD = (6,35)  TAIL = (12,37)
# Tail has been in 124 positions!
# HEAD = (6,36)  TAIL = (12,37)
# Tail has been in 124 positions!
# HEAD = (10,36)  TAIL = (12,37)
# Tail has been in 124 positions!
# HEAD = (5,36)  TAIL = (12,37)
# Tail has been in 124 positions!
# HEAD = (5,34)  TAIL = (12,37)
# Tail has been in 124 positions!
# HEAD = (3,34)  TAIL = (11,36)
# Tail has been in 125 positions!
# HEAD = (3,31)  TAIL = (10,35)
# Tail has been in 126 positions!
# HEAD = (9,31)  TAIL = (10,35)
# Tail has been in 126 positions!
# HEAD = (9,37)  TAIL = (10,35)
# Tail has been in 126 positions!
# HEAD = (14,37)  TAIL = (10,35)
# Tail has been in 126 positions!
# HEAD = (14,35)  TAIL = (10,35)
# Tail has been in 126 positions!
# HEAD = (14,40)  TAIL = (10,35)
# Tail has been in 126 positions!
# HEAD = (7,40)  TAIL = (10,35)
# Tail has been in 126 positions!
# HEAD = (13,40)  TAIL = (10,35)
# Tail has been in 126 positions!
# HEAD = (10,40)  TAIL = (10,35)
# Tail has been in 126 positions!
# HEAD = (10,47)  TAIL = (10,38)
# Tail has been in 129 positions!
# HEAD = (14,47)  TAIL = (12,40)
# Tail has been in 131 positions!
# HEAD = (14,40)  TAIL = (12,40)
# Tail has been in 131 positions!
# HEAD = (19,40)  TAIL = (12,40)
# Tail has been in 131 positions!
# HEAD = (19,47)  TAIL = (14,42)
# Tail has been in 132 positions!
# HEAD = (25,47)  TAIL = (17,45)
# Tail has been in 135 positions!
# HEAD = (25,52)  TAIL = (19,47)
# Tail has been in 137 positions!
# HEAD = (32,52)  TAIL = (23,51)
# Tail has been in 141 positions!
# HEAD = (32,56)  TAIL = (25,53)
# Tail has been in 143 positions!
# HEAD = (32,52)  TAIL = (25,53)
# Tail has been in 143 positions!
# HEAD = (31,52)  TAIL = (25,53)
# Tail has been in 143 positions!
# HEAD = (33,52)  TAIL = (25,53)
# Tail has been in 143 positions!
# HEAD = (33,47)  TAIL = (28,51)
# Tail has been in 146 positions!
# HEAD = (30,47)  TAIL = (28,51)
# Tail has been in 146 positions!
# HEAD = (36,47)  TAIL = (29,50)
# Tail has been in 147 positions!
# HEAD = (36,44)  TAIL = (30,49)
# Tail has been in 148 positions!
# HEAD = (42,44)  TAIL = (34,45)
# Tail has been in 152 positions!
# HEAD = (42,40)  TAIL = (36,43)
# Tail has been in 154 positions!
# HEAD = (42,44)  TAIL = (36,43)
# Tail has been in 154 positions!
# HEAD = (36,44)  TAIL = (36,43)
# Tail has been in 154 positions!
# HEAD = (36,49)  TAIL = (36,43)
# Tail has been in 154 positions!
# HEAD = (36,46)  TAIL = (36,43)
# Tail has been in 154 positions!
# HEAD = (36,51)  TAIL = (36,43)
# Tail has been in 154 positions!
# HEAD = (36,46)  TAIL = (36,43)
# Tail has been in 154 positions!
# HEAD = (38,46)  TAIL = (36,43)
# Tail has been in 154 positions!
# HEAD = (34,46)  TAIL = (36,43)
# Tail has been in 154 positions!
# HEAD = (34,45)  TAIL = (36,43)
# Tail has been in 154 positions!
# HEAD = (30,45)  TAIL = (36,43)
# Tail has been in 154 positions!
# HEAD = (30,49)  TAIL = (35,44)
# Tail has been in 154 positions!
# HEAD = (26,49)  TAIL = (33,46)
# Tail has been in 154 positions!
# HEAD = (26,47)  TAIL = (33,46)
# Tail has been in 154 positions!
# HEAD = (33,47)  TAIL = (33,46)
# Tail has been in 154 positions!
# HEAD = (33,45)  TAIL = (33,46)
# Tail has been in 154 positions!
# HEAD = (27,45)  TAIL = (33,46)
# Tail has been in 154 positions!
# HEAD = (32,45)  TAIL = (33,46)
# Tail has been in 154 positions!
# HEAD = (25,45)  TAIL = (33,46)
# Tail has been in 154 positions!
# HEAD = (25,50)  TAIL = (32,47)
# Tail has been in 154 positions!
# HEAD = (29,50)  TAIL = (32,47)
# Tail has been in 154 positions!
# HEAD = (27,50)  TAIL = (32,47)
# Tail has been in 154 positions!
# HEAD = (28,50)  TAIL = (32,47)
# Tail has been in 154 positions!
# HEAD = (28,57)  TAIL = (30,49)
# Tail has been in 154 positions!
# HEAD = (34,57)  TAIL = (31,51)
# Tail has been in 156 positions!
# HEAD = (34,50)  TAIL = (31,51)
# Tail has been in 156 positions!
# HEAD = (28,50)  TAIL = (31,51)
# Tail has been in 156 positions!
# HEAD = (28,48)  TAIL = (31,51)
# Tail has been in 156 positions!
# HEAD = (23,48)  TAIL = (31,51)
# Tail has been in 156 positions!
# HEAD = (23,47)  TAIL = (31,51)
# Tail has been in 156 positions!
# HEAD = (23,53)  TAIL = (30,50)
# Tail has been in 156 positions!
# HEAD = (21,53)  TAIL = (29,51)
# Tail has been in 157 positions!
# HEAD = (21,49)  TAIL = (28,51)
# Tail has been in 157 positions!
# HEAD = (15,49)  TAIL = (24,49)
# Tail has been in 161 positions!
# HEAD = (15,48)  TAIL = (24,49)
# Tail has been in 161 positions!
# HEAD = (10,48)  TAIL = (19,48)
# Tail has been in 165 positions!
# HEAD = (16,48)  TAIL = (19,48)
# Tail has been in 165 positions!
# HEAD = (16,42)  TAIL = (19,48)
# Tail has been in 165 positions!
# HEAD = (12,42)  TAIL = (17,46)
# Tail has been in 167 positions!
# HEAD = (12,38)  TAIL = (15,44)
# Tail has been in 169 positions!
# HEAD = (17,38)  TAIL = (15,44)
# Tail has been in 169 positions!
# HEAD = (13,38)  TAIL = (15,44)
# Tail has been in 169 positions!
# HEAD = (13,36)  TAIL = (15,44)
# Tail has been in 169 positions!
# HEAD = (13,41)  TAIL = (15,44)
# Tail has been in 169 positions!
# HEAD = (13,39)  TAIL = (15,44)
# Tail has been in 169 positions!
# HEAD = (6,39)  TAIL = (13,42)
# Tail has been in 170 positions!
# HEAD = (7,39)  TAIL = (13,42)
# Tail has been in 170 positions!
# HEAD = (7,34)  TAIL = (11,40)
# Tail has been in 170 positions!
# HEAD = (10,34)  TAIL = (11,40)
# Tail has been in 170 positions!
# HEAD = (6,34)  TAIL = (11,40)
# Tail has been in 170 positions!
# HEAD = (6,27)  TAIL = (7,36)
# Tail has been in 170 positions!
# HEAD = (6,29)  TAIL = (7,36)
# Tail has been in 170 positions!
# HEAD = (9,29)  TAIL = (7,36)
# Tail has been in 170 positions!
# HEAD = (9,30)  TAIL = (7,36)
# Tail has been in 170 positions!
# HEAD = (8,30)  TAIL = (7,36)
# Tail has been in 170 positions!
# HEAD = (8,33)  TAIL = (7,36)
# Tail has been in 170 positions!
# HEAD = (8,26)  TAIL = (7,35)
# Tail has been in 171 positions!
# HEAD = (1,26)  TAIL = (5,32)
# Tail has been in 174 positions!
# HEAD = (1,24)  TAIL = (4,31)
# Tail has been in 175 positions!
# HEAD = (1,29)  TAIL = (4,31)
# Tail has been in 175 positions!
# HEAD = (1,27)  TAIL = (4,31)
# Tail has been in 175 positions!
# HEAD = (1,30)  TAIL = (4,31)
# Tail has been in 175 positions!
# HEAD = (-2,30)  TAIL = (4,31)
# Tail has been in 175 positions!
# HEAD = (-2,35)  TAIL = (3,31)
# Tail has been in 176 positions!
# HEAD = (-3,35)  TAIL = (3,31)
# Tail has been in 176 positions!
# HEAD = (-3,39)  TAIL = (1,33)
# Tail has been in 178 positions!
# HEAD = (-4,39)  TAIL = (1,33)
# Tail has been in 178 positions!
# HEAD = (-4,37)  TAIL = (1,33)
# Tail has been in 178 positions!
# HEAD = (-4,38)  TAIL = (1,33)
# Tail has been in 178 positions!
# HEAD = (-4,31)  TAIL = (1,33)
# Tail has been in 178 positions!
# HEAD = (1,31)  TAIL = (1,33)
# Tail has been in 178 positions!
# HEAD = (1,35)  TAIL = (1,33)
# Tail has been in 178 positions!
# HEAD = (-1,35)  TAIL = (1,33)
# Tail has been in 178 positions!
# HEAD = (-1,28)  TAIL = (1,33)
# Tail has been in 178 positions!
# HEAD = (-1,34)  TAIL = (1,33)
# Tail has been in 178 positions!
# HEAD = (-1,31)  TAIL = (1,33)
# Tail has been in 178 positions!
# HEAD = (-1,39)  TAIL = (1,33)
# Tail has been in 178 positions!
# HEAD = (-7,39)  TAIL = (-1,35)
# Tail has been in 180 positions!
# HEAD = (-6,39)  TAIL = (-1,35)
# Tail has been in 180 positions!
# HEAD = (-6,46)  TAIL = (-4,38)
# Tail has been in 183 positions!
# HEAD = (-6,38)  TAIL = (-4,38)
# Tail has been in 183 positions!
# HEAD = (-1,38)  TAIL = (-4,38)
# Tail has been in 183 positions!
# HEAD = (-1,36)  TAIL = (-4,38)
# Tail has been in 183 positions!
# HEAD = (-4,36)  TAIL = (-4,38)
# Tail has been in 183 positions!
# HEAD = (-4,29)  TAIL = (-4,38)
# Tail has been in 183 positions!
# HEAD = (-4,32)  TAIL = (-4,38)
# Tail has been in 183 positions!
# HEAD = (-4,30)  TAIL = (-4,38)
# Tail has been in 183 positions!
# HEAD = (0,30)  TAIL = (-3,37)
# Tail has been in 183 positions!
# HEAD = (-1,30)  TAIL = (-3,37)
# Tail has been in 183 positions!
# HEAD = (-1,36)  TAIL = (-3,37)
# Tail has been in 183 positions!
# HEAD = (-1,32)  TAIL = (-3,37)
# Tail has been in 183 positions!
# HEAD = (1,32)  TAIL = (-3,37)
# Tail has been in 183 positions!
# HEAD = (1,39)  TAIL = (-3,37)
# Tail has been in 183 positions!
# HEAD = (-5,39)  TAIL = (-3,37)
# Tail has been in 183 positions!
# HEAD = (-5,42)  TAIL = (-3,37)
# Tail has been in 183 positions!
# HEAD = (-11,42)  TAIL = (-4,38)
# Tail has been in 183 positions!
# HEAD = (-11,39)  TAIL = (-4,38)
# Tail has been in 183 positions!
# HEAD = (-16,39)  TAIL = (-7,39)
# Tail has been in 186 positions!
# HEAD = (-16,45)  TAIL = (-10,42)
# Tail has been in 189 positions!
# HEAD = (-18,45)  TAIL = (-11,43)
# Tail has been in 190 positions!
# HEAD = (-17,45)  TAIL = (-11,43)
# Tail has been in 190 positions!
# HEAD = (-17,38)  TAIL = (-12,42)
# Tail has been in 191 positions!
# HEAD = (-10,38)  TAIL = (-12,42)
# Tail has been in 191 positions!
# HEAD = (-11,38)  TAIL = (-12,42)
# Tail has been in 191 positions!
# HEAD = (-11,32)  TAIL = (-11,41)
# Tail has been in 192 positions!
# HEAD = (-11,34)  TAIL = (-11,41)
# Tail has been in 192 positions!
# HEAD = (-3,34)  TAIL = (-8,38)
# Tail has been in 195 positions!
# HEAD = (-3,31)  TAIL = (-7,37)
# Tail has been in 196 positions!
# HEAD = (-2,31)  TAIL = (-7,37)
# Tail has been in 196 positions!
# HEAD = (-2,38)  TAIL = (-7,37)
# Tail has been in 196 positions!
# HEAD = (-2,34)  TAIL = (-7,37)
# Tail has been in 196 positions!
# HEAD = (-2,42)  TAIL = (-6,37)
# Tail has been in 197 positions!
# HEAD = (4,42)  TAIL = (-3,40)
# Tail has been in 200 positions!
# HEAD = (3,42)  TAIL = (-3,40)
# Tail has been in 200 positions!
# HEAD = (3,38)  TAIL = (-3,40)
# Tail has been in 200 positions!
# HEAD = (3,41)  TAIL = (-3,40)
# Tail has been in 200 positions!
# HEAD = (-5,41)  TAIL = (-3,40)
# Tail has been in 200 positions!
# HEAD = (-5,40)  TAIL = (-3,40)
# Tail has been in 200 positions!
# HEAD = (-1,40)  TAIL = (-3,40)
# Tail has been in 200 positions!
# HEAD = (-1,38)  TAIL = (-3,40)
# Tail has been in 200 positions!
# HEAD = (-1,46)  TAIL = (-3,40)
# Tail has been in 200 positions!
# HEAD = (-1,40)  TAIL = (-3,40)
# Tail has been in 200 positions!
# HEAD = (-3,40)  TAIL = (-3,40)
# Tail has been in 200 positions!
# HEAD = (-3,46)  TAIL = (-3,40)
# Tail has been in 200 positions!
# HEAD = (-1,46)  TAIL = (-3,40)
# Tail has been in 200 positions!
# HEAD = (-1,54)  TAIL = (-1,45)
# Tail has been in 205 positions!
# HEAD = (-1,50)  TAIL = (-1,45)
# Tail has been in 205 positions!
# HEAD = (7,50)  TAIL = (1,47)
# Tail has been in 207 positions!
# HEAD = (7,45)  TAIL = (1,47)
# Tail has been in 207 positions!
# HEAD = (7,49)  TAIL = (1,47)
# Tail has been in 207 positions!
# HEAD = (7,42)  TAIL = (2,46)
# Tail has been in 208 positions!
# HEAD = (7,50)  TAIL = (2,46)
# Tail has been in 208 positions!
# HEAD = (5,50)  TAIL = (2,46)
# Tail has been in 208 positions!
# HEAD = (5,56)  TAIL = (4,48)
# Tail has been in 210 positions!
# HEAD = (5,51)  TAIL = (4,48)
# Tail has been in 210 positions!
# HEAD = (10,51)  TAIL = (4,48)
# Tail has been in 210 positions!
# HEAD = (10,47)  TAIL = (4,48)
# Tail has been in 210 positions!
# HEAD = (18,47)  TAIL = (9,47)
# Tail has been in 215 positions!
# HEAD = (18,52)  TAIL = (11,49)
# Tail has been in 217 positions!
# HEAD = (22,52)  TAIL = (13,51)
# Tail has been in 219 positions!
# HEAD = (14,52)  TAIL = (13,51)
# Tail has been in 219 positions!
# HEAD = (14,59)  TAIL = (13,51)
# Tail has been in 219 positions!
# HEAD = (19,59)  TAIL = (15,53)
# Tail has been in 221 positions!
# HEAD = (19,56)  TAIL = (15,53)
# Tail has been in 221 positions!
# HEAD = (26,56)  TAIL = (17,55)
# Tail has been in 223 positions!
# HEAD = (20,56)  TAIL = (17,55)
# Tail has been in 223 positions!
# HEAD = (20,55)  TAIL = (17,55)
# Tail has been in 223 positions!
# HEAD = (15,55)  TAIL = (17,55)
# Tail has been in 223 positions!
# HEAD = (15,62)  TAIL = (17,55)
# Tail has been in 223 positions!
# HEAD = (20,62)  TAIL = (17,55)
# Tail has been in 223 positions!
# HEAD = (20,66)  TAIL = (19,57)
# Tail has been in 225 positions!
# HEAD = (23,66)  TAIL = (20,58)
# Tail has been in 226 positions!
# HEAD = (18,66)  TAIL = (20,59)
# Tail has been in 227 positions!
# HEAD = (18,67)  TAIL = (20,59)
# Tail has been in 227 positions!
# HEAD = (25,67)  TAIL = (22,61)
# Tail has been in 229 positions!
# HEAD = (25,66)  TAIL = (22,61)
# Tail has been in 229 positions!
# HEAD = (33,66)  TAIL = (25,64)
# Tail has been in 232 positions!
# HEAD = (33,68)  TAIL = (26,65)
# Tail has been in 233 positions!
# HEAD = (28,68)  TAIL = (26,65)
# Tail has been in 233 positions!
# HEAD = (28,73)  TAIL = (26,65)
# Tail has been in 233 positions!
# HEAD = (29,73)  TAIL = (26,65)
# Tail has been in 233 positions!
# HEAD = (22,73)  TAIL = (25,67)
# Tail has been in 235 positions!
# HEAD = (22,75)  TAIL = (24,68)
# Tail has been in 236 positions!
# HEAD = (22,72)  TAIL = (24,68)
# Tail has been in 236 positions!
# HEAD = (22,75)  TAIL = (24,68)
# Tail has been in 236 positions!
# HEAD = (30,75)  TAIL = (26,70)
# Tail has been in 238 positions!
# HEAD = (30,81)  TAIL = (29,73)
# Tail has been in 241 positions!
# HEAD = (32,81)  TAIL = (30,74)
# Tail has been in 242 positions!
# HEAD = (32,82)  TAIL = (30,74)
# Tail has been in 242 positions!
# HEAD = (36,82)  TAIL = (32,76)
# Tail has been in 244 positions!
# HEAD = (36,77)  TAIL = (32,76)
# Tail has been in 244 positions!
# HEAD = (36,82)  TAIL = (32,76)
# Tail has been in 244 positions!
# HEAD = (37,82)  TAIL = (32,76)
# Tail has been in 244 positions!
# HEAD = (37,84)  TAIL = (33,77)
# Tail has been in 245 positions!
# HEAD = (36,84)  TAIL = (33,77)
# Tail has been in 245 positions!
# HEAD = (39,84)  TAIL = (34,78)
# Tail has been in 246 positions!
# HEAD = (35,84)  TAIL = (34,78)
# Tail has been in 246 positions!
# HEAD = (39,84)  TAIL = (34,78)
# Tail has been in 246 positions!
# HEAD = (39,78)  TAIL = (35,79)
# Tail has been in 247 positions!
# HEAD = (44,78)  TAIL = (35,79)
# Tail has been in 247 positions!
# HEAD = (44,81)  TAIL = (36,79)
# Tail has been in 248 positions!
# HEAD = (44,77)  TAIL = (36,79)
# Tail has been in 248 positions!
# HEAD = (51,77)  TAIL = (42,77)
# Tail has been in 254 positions!
# HEAD = (44,77)  TAIL = (42,77)
# Tail has been in 254 positions!
# HEAD = (44,70)  TAIL = (42,77)
# Tail has been in 254 positions!
# HEAD = (48,70)  TAIL = (44,75)
# Tail has been in 256 positions!
# HEAD = (48,75)  TAIL = (44,75)
# ...
# HEAD = (185,64)  TAIL = (179,60)
# Tail has been in 1833 positions!
# HEAD = (182,64)  TAIL = (179,60)
# Tail has been in 1833 positions!
# HEAD = (182,73)  TAIL = (182,64)
# Tail has been in 1837 positions!
# HEAD = (176,73)  TAIL = (179,67)
# Tail has been in 1840 positions!
# HEAD = (176,90)  TAIL = (176,81)
# Tail has been in 1854 positions!
# HEAD = (161,90)  TAIL = (169,88)
# Tail has been in 1861 positions!
# HEAD = (175,90)  TAIL = (169,88)
# Tail has been in 1861 positions!
# HEAD = (175,84)  TAIL = (169,88)
# Tail has been in 1861 positions!
# HEAD = (175,97)  TAIL = (172,90)
# Tail has been in 1864 positions!
# HEAD = (186,97)  TAIL = (177,95)
# Tail has been in 1869 positions!
# HEAD = (174,97)  TAIL = (177,95)
# Tail has been in 1869 positions!
# HEAD = (190,97)  TAIL = (181,97)
# Tail has been in 1873 positions!
# HEAD = (190,101)  TAIL = (183,99)
# Tail has been in 1875 positions!
# HEAD = (190,99)  TAIL = (183,99)
# Tail has been in 1875 positions!
# HEAD = (190,103)  TAIL = (184,100)
# Tail has been in 1876 positions!
# HEAD = (207,103)  TAIL = (198,103)
# Tail has been in 1890 positions!
# HEAD = (207,94)  TAIL = (202,99)
# Tail has been in 1894 positions!
# HEAD = (216,94)  TAIL = (207,94)
# Tail has been in 1899 positions!
# HEAD = (216,87)  TAIL = (210,91)
# Tail has been in 1902 positions!
# HEAD = (228,87)  TAIL = (219,87)
# Tail has been in 1911 positions!
# HEAD = (219,87)  TAIL = (219,87)
# Tail has been in 1911 positions!
# HEAD = (235,87)  TAIL = (226,87)
# Tail has been in 1918 positions!
# HEAD = (235,73)  TAIL = (233,80)
# Tail has been in 1925 positions!
# HEAD = (235,74)  TAIL = (233,80)
# Tail has been in 1925 positions!
# HEAD = (247,74)  TAIL = (238,75)
# Tail has been in 1930 positions!
# HEAD = (247,85)  TAIL = (243,79)
# Tail has been in 1935 positions!
# HEAD = (247,75)  TAIL = (243,79)
# Tail has been in 1935 positions!
# HEAD = (237,75)  TAIL = (243,79)
# Tail has been in 1935 positions!
# HEAD = (237,63)  TAIL = (237,72)
# Tail has been in 1938 positions!
# HEAD = (249,63)  TAIL = (243,66)
# Tail has been in 1944 positions!
# HEAD = (249,70)  TAIL = (243,66)
# Tail has been in 1944 positions!
# HEAD = (249,58)  TAIL = (245,64)
# Tail has been in 1946 positions!
# HEAD = (249,67)  TAIL = (245,64)
# Tail has been in 1946 positions!
# HEAD = (249,52)  TAIL = (248,61)
# Tail has been in 1949 positions!
# HEAD = (256,52)  TAIL = (251,58)
# Tail has been in 1952 positions!
# HEAD = (256,53)  TAIL = (251,58)
# Tail has been in 1952 positions!
# HEAD = (260,53)  TAIL = (253,56)
# Tail has been in 1954 positions!
# HEAD = (260,64)  TAIL = (256,58)
# Tail has been in 1957 positions!
# HEAD = (278,64)  TAIL = (269,64)
# Tail has been in 1970 positions!
# HEAD = (272,64)  TAIL = (269,64)
# Tail has been in 1970 positions!
# HEAD = (272,52)  TAIL = (272,61)
# Tail has been in 1973 positions!
# HEAD = (272,66)  TAIL = (272,61)
# Tail has been in 1973 positions!
# HEAD = (284,66)  TAIL = (276,65)
# Tail has been in 1977 positions!
# HEAD = (284,64)  TAIL = (276,65)
# Tail has been in 1977 positions!
# HEAD = (290,64)  TAIL = (281,64)
# Tail has been in 1982 positions!
# HEAD = (290,55)  TAIL = (285,60)
# Tail has been in 1986 positions!
# HEAD = (286,55)  TAIL = (285,60)
# Tail has been in 1986 positions!
# HEAD = (286,66)  TAIL = (285,60)
# Tail has been in 1986 positions!
# HEAD = (273,66)  TAIL = (281,64)
# Tail has been in 1986 positions!
# HEAD = (273,52)  TAIL = (275,59)
# Tail has been in 1991 positions!
# HEAD = (268,52)  TAIL = (273,57)
# Tail has been in 1993 positions!
# HEAD = (281,52)  TAIL = (275,55)
# Tail has been in 1995 positions!
# HEAD = (269,52)  TAIL = (275,55)
# Tail has been in 1995 positions!
# HEAD = (269,69)  TAIL = (270,60)
# Tail has been in 1998 positions!
# HEAD = (258,69)  TAIL = (265,65)
# Tail has been in 2002 positions!
# HEAD = (266,69)  TAIL = (265,65)
# Tail has been in 2002 positions!
# HEAD = (263,69)  TAIL = (265,65)
# Tail has been in 2002 positions!
# HEAD = (263,63)  TAIL = (265,65)
# Tail has been in 2002 positions!
# HEAD = (263,67)  TAIL = (265,65)
# Tail has been in 2002 positions!
# HEAD = (279,67)  TAIL = (270,67)
# Tail has been in 2008 positions!
# HEAD = (279,53)  TAIL = (277,60)
# Tail has been in 2014 positions!
# HEAD = (279,63)  TAIL = (277,60)
# Tail has been in 2014 positions!
# HEAD = (291,63)  TAIL = (282,63)
# Tail has been in 2018 positions!
# HEAD = (284,63)  TAIL = (282,63)
# Tail has been in 2018 positions!
# HEAD = (290,63)  TAIL = (282,63)
# Tail has been in 2018 positions!
# HEAD = (281,63)  TAIL = (282,63)
# Tail has been in 2018 positions!
# HEAD = (281,50)  TAIL = (281,59)
# Tail has been in 2022 positions!
# HEAD = (281,56)  TAIL = (281,59)
# Tail has been in 2022 positions!
# HEAD = (281,41)  TAIL = (281,50)
# Tail has been in 2031 positions!
# HEAD = (298,41)  TAIL = (289,42)
# Tail has been in 2039 positions!
# HEAD = (297,41)  TAIL = (289,42)
# Tail has been in 2039 positions!
# HEAD = (297,34)  TAIL = (292,39)
# Tail has been in 2042 positions!
# HEAD = (291,34)  TAIL = (292,39)
# Tail has been in 2042 positions!
# HEAD = (307,34)  TAIL = (298,34)
# Tail has been in 2048 positions!
# HEAD = (307,21)  TAIL = (304,28)
# Tail has been in 2054 positions!
# HEAD = (302,21)  TAIL = (304,28)
# Tail has been in 2054 positions!
# HEAD = (318,21)  TAIL = (309,23)
# Tail has been in 2059 positions!
# HEAD = (318,26)  TAIL = (311,23)
# Tail has been in 2061 positions!
# HEAD = (318,24)  TAIL = (311,23)
# Tail has been in 2061 positions!
# HEAD = (335,24)  TAIL = (326,24)
# Tail has been in 2076 positions!
# HEAD = (318,24)  TAIL = (326,24)
# Tail has been in 2076 positions!
# HEAD = (318,42)  TAIL = (318,33)
# Tail has been in 2085 positions!
# HEAD = (308,42)  TAIL = (313,38)
# Tail has been in 2090 positions!
# HEAD = (308,28)  TAIL = (310,35)
# Tail has been in 2093 positions!
# HEAD = (308,37)  TAIL = (310,35)
# Tail has been in 2093 positions!
# HEAD = (308,28)  TAIL = (310,35)
# Tail has been in 2093 positions!
# HEAD = (308,29)  TAIL = (310,35)
# Tail has been in 2093 positions!
# HEAD = (300,29)  TAIL = (307,32)
# Tail has been in 2096 positions!
# HEAD = (305,29)  TAIL = (307,32)
# Tail has been in 2096 positions!
# HEAD = (305,24)  TAIL = (307,32)
# Tail has been in 2096 positions!
# HEAD = (305,36)  TAIL = (307,32)
# Tail has been in 2096 positions!
# HEAD = (305,35)  TAIL = (307,32)
# Tail has been in 2096 positions!
# HEAD = (297,35)  TAIL = (305,33)
# Tail has been in 2098 positions!
# HEAD = (297,48)  TAIL = (298,40)
# Tail has been in 2105 positions!
# HEAD = (303,48)  TAIL = (300,42)
# Tail has been in 2107 positions!
# HEAD = (303,36)  TAIL = (300,42)
# Tail has been in 2107 positions!
# HEAD = (309,36)  TAIL = (303,39)
# Tail has been in 2110 positions!
# HEAD = (309,34)  TAIL = (304,38)
# Tail has been in 2111 positions!
# HEAD = (301,34)  TAIL = (304,38)
# Tail has been in 2111 positions!
# HEAD = (301,45)  TAIL = (304,38)
# Tail has been in 2111 positions!
# HEAD = (287,45)  TAIL = (296,45)
# Tail has been in 2115 positions!
# HEAD = (293,45)  TAIL = (296,45)
# Tail has been in 2115 positions!
# HEAD = (276,45)  TAIL = (285,45)
# Tail has been in 2125 positions!
# HEAD = (276,44)  TAIL = (285,45)
# Tail has been in 2125 positions!
# HEAD = (277,44)  TAIL = (285,45)
# Tail has been in 2125 positions!
# HEAD = (277,41)  TAIL = (284,44)
# Tail has been in 2126 positions!
# HEAD = (277,52)  TAIL = (281,47)
# Tail has been in 2129 positions!
# HEAD = (277,38)  TAIL = (279,45)
# Tail has been in 2131 positions!
# HEAD = (285,38)  TAIL = (281,43)
# Tail has been in 2133 positions!
# HEAD = (285,40)  TAIL = (281,43)
# Tail has been in 2133 positions!
# HEAD = (286,40)  TAIL = (281,43)
# Tail has been in 2133 positions!
# HEAD = (286,57)  TAIL = (286,48)
# Tail has been in 2137 positions!
# HEAD = (272,57)  TAIL = (279,55)
# Tail has been in 2143 positions!
# HEAD = (272,72)  TAIL = (272,63)
# Tail has been in 2150 positions!
# HEAD = (272,55)  TAIL = (272,63)
# Tail has been in 2150 positions!
# HEAD = (257,55)  TAIL = (266,57)
# Tail has been in 2155 positions!
# HEAD = (257,66)  TAIL = (261,60)
# Tail has been in 2160 positions!
# HEAD = (250,66)  TAIL = (258,63)
# Tail has been in 2163 positions!
# HEAD = (250,64)  TAIL = (258,63)
# Tail has been in 2163 positions!
# HEAD = (234,64)  TAIL = (243,64)
# Tail has been in 2177 positions!
# HEAD = (234,57)  TAIL = (240,61)
# Tail has been in 2180 positions!
# HEAD = (220,57)  TAIL = (229,57)
# Tail has been in 2191 positions!
# HEAD = (220,71)  TAIL = (222,64)
# Tail has been in 2198 positions!
# HEAD = (220,66)  TAIL = (222,64)
# Tail has been in 2198 positions!
# HEAD = (224,66)  TAIL = (222,64)
# Tail has been in 2198 positions!
# HEAD = (224,73)  TAIL = (222,64)
# Tail has been in 2198 positions!
# HEAD = (224,69)  TAIL = (222,64)
# Tail has been in 2198 positions!
# HEAD = (236,69)  TAIL = (227,69)
# Tail has been in 2203 positions!
# HEAD = (225,69)  TAIL = (227,69)
# Tail has been in 2203 positions!
# HEAD = (225,65)  TAIL = (227,69)
# Tail has been in 2203 positions!
# HEAD = (225,84)  TAIL = (225,75)
# Tail has been in 2209 positions!
# HEAD = (209,84)  TAIL = (217,83)
# Tail has been in 2217 positions!
# HEAD = (222,84)  TAIL = (217,83)
# Tail has been in 2217 positions!
# HEAD = (221,84)  TAIL = (217,83)
# Tail has been in 2217 positions!
# HEAD = (234,84)  TAIL = (225,84)
# Tail has been in 2225 positions!
# HEAD = (234,96)  TAIL = (231,90)
# Tail has been in 2230 positions!
# HEAD = (246,96)  TAIL = (237,96)
# Tail has been in 2236 positions!
# HEAD = (246,106)  TAIL = (242,101)
# Tail has been in 2241 positions!
# HEAD = (239,106)  TAIL = (242,101)
# Tail has been in 2241 positions!
# HEAD = (248,106)  TAIL = (243,102)
# Tail has been in 2242 positions!
# HEAD = (248,121)  TAIL = (248,112)
# Tail has been in 2252 positions!
# HEAD = (248,118)  TAIL = (248,112)
# Tail has been in 2252 positions!
# HEAD = (260,118)  TAIL = (252,116)
# Tail has been in 2256 positions!
# HEAD = (260,126)  TAIL = (256,120)
# Tail has been in 2260 positions!
# HEAD = (255,126)  TAIL = (256,120)
# Tail has been in 2260 positions!
# HEAD = (269,126)  TAIL = (261,125)
# Tail has been in 2265 positions!
# HEAD = (269,130)  TAIL = (263,127)
# Tail has been in 2267 positions!
# HEAD = (269,128)  TAIL = (263,127)
# Tail has been in 2267 positions!
# HEAD = (267,128)  TAIL = (263,127)
# Tail has been in 2267 positions!
# HEAD = (267,136)  TAIL = (265,129)
# Tail has been in 2269 positions!
# HEAD = (261,136)  TAIL = (264,130)
# Tail has been in 2270 positions!
# HEAD = (261,126)  TAIL = (264,130)
# Tail has been in 2270 positions!
# HEAD = (243,126)  TAIL = (252,126)
# Tail has been in 2282 positions!
# HEAD = (243,130)  TAIL = (250,128)
# Tail has been in 2284 positions!
# HEAD = (243,122)  TAIL = (248,126)
# Tail has been in 2286 positions!
# HEAD = (258,122)  TAIL = (250,124)
# Tail has been in 2288 positions!
# HEAD = (258,111)  TAIL = (255,119)
# Tail has been in 2292 positions!
# HEAD = (272,111)  TAIL = (263,111)
# Tail has been in 2300 positions!
# HEAD = (272,95)  TAIL = (271,103)
# Tail has been in 2308 positions!
# HEAD = (286,95)  TAIL = (278,96)
# Tail has been in 2315 positions!
# HEAD = (286,91)  TAIL = (280,94)
# Tail has been in 2317 positions!
# HEAD = (295,91)  TAIL = (286,91)
# Tail has been in 2323 positions!
# HEAD = (295,105)  TAIL = (293,98)
# Tail has been in 2330 positions!
# HEAD = (293,105)  TAIL = (293,98)
# Tail has been in 2330 positions!
# HEAD = (295,105)  TAIL = (293,98)
# Tail has been in 2330 positions!
# HEAD = (295,121)  TAIL = (295,112)
# Tail has been in 2344 positions!
# HEAD = (297,121)  TAIL = (296,113)
# Tail has been in 2345 positions!
# HEAD = (297,139)  TAIL = (297,130)
# Tail has been in 2362 positions!
# HEAD = (297,133)  TAIL = (297,130)
# Tail has been in 2362 positions!
# HEAD = (313,133)  TAIL = (304,133)
# Tail has been in 2369 positions!
# HEAD = (313,135)  TAIL = (305,134)
# Tail has been in 2370 positions!
# HEAD = (306,135)  TAIL = (305,134)
# Tail has been in 2370 positions!
# HEAD = (306,141)  TAIL = (305,134)
# Tail has been in 2370 positions!
# HEAD = (306,137)  TAIL = (305,134)
# Tail has been in 2370 positions!
# HEAD = (297,137)  TAIL = (304,135)
# Tail has been in 2371 positions!
# HEAD = (297,155)  TAIL = (297,146)
# Tail has been in 2382 positions!
# HEAD = (307,155)  TAIL = (302,151)
# Tail has been in 2387 positions!
# HEAD = (290,155)  TAIL = (299,154)
# Tail has been in 2390 positions!
# HEAD = (302,155)  TAIL = (299,154)
# Tail has been in 2390 positions!
# HEAD = (302,162)  TAIL = (299,155)
# Tail has been in 2391 positions!
# HEAD = (292,162)  TAIL = (297,158)
# Tail has been in 2394 positions!
# HEAD = (292,167)  TAIL = (295,160)
# Tail has been in 2396 positions!
# HEAD = (292,152)  TAIL = (294,159)
# Tail has been in 2397 positions!
# HEAD = (292,158)  TAIL = (294,159)
# Tail has been in 2397 positions!
# HEAD = (278,158)  TAIL = (287,158)
# Tail has been in 2404 positions!
# HEAD = (278,175)  TAIL = (279,166)
# Tail has been in 2412 positions!
# HEAD = (289,175)  TAIL = (283,171)
# Tail has been in 2417 positions!
# HEAD = (289,177)  TAIL = (284,172)
# Tail has been in 2418 positions!
# HEAD = (295,177)  TAIL = (287,175)
# Tail has been in 2421 positions!
# HEAD = (290,177)  TAIL = (287,175)
# Tail has been in 2421 positions!
# HEAD = (290,175)  TAIL = (287,175)
# Tail has been in 2421 positions!
# HEAD = (290,190)  TAIL = (290,181)
# Tail has been in 2427 positions!
# HEAD = (290,184)  TAIL = (290,181)
# Tail has been in 2427 positions!
# HEAD = (290,188)  TAIL = (290,181)
# Tail has been in 2427 positions!
# HEAD = (306,188)  TAIL = (297,188)
# Tail has been in 2434 positions!
# HEAD = (306,181)  TAIL = (300,185)
# Tail has been in 2437 positions!
# HEAD = (291,181)  TAIL = (299,183)
# Tail has been in 2439 positions!
# HEAD = (300,181)  TAIL = (299,183)
# Tail has been in 2439 positions!
# HEAD = (300,175)  TAIL = (299,183)
# Tail has been in 2439 positions!
# HEAD = (315,175)  TAIL = (306,175)
# Tail has been in 2447 positions!
# HEAD = (314,175)  TAIL = (306,175)
# Tail has been in 2447 positions!
# HEAD = (316,175)  TAIL = (307,175)
# Tail has been in 2448 positions!
# HEAD = (311,175)  TAIL = (307,175)
# Tail has been in 2448 positions!
# HEAD = (311,194)  TAIL = (311,185)
# Tail has been in 2458 positions!
# HEAD = (305,194)  TAIL = (308,188)
# Tail has been in 2461 positions!
# HEAD = (305,209)  TAIL = (305,200)
# Tail has been in 2473 positions!
# HEAD = (321,209)  TAIL = (313,208)
# Tail has been in 2481 positions!
# HEAD = (309,209)  TAIL = (313,208)
# Tail has been in 2481 positions!
# HEAD = (309,200)  TAIL = (312,207)
# Tail has been in 2481 positions!
# HEAD = (309,215)  TAIL = (311,208)
# Tail has been in 2482 positions!
# HEAD = (309,208)  TAIL = (311,208)
# Tail has been in 2482 positions!
# HEAD = (299,208)  TAIL = (308,208)
# Tail has been in 2485 positions!
# HEAD = (299,217)  TAIL = (304,212)
# Tail has been in 2489 positions!
# HEAD = (299,202)  TAIL = (301,209)
# Tail has been in 2492 positions!
# HEAD = (286,202)  TAIL = (295,203)
# Tail has been in 2498 positions!
# HEAD = (287,202)  TAIL = (295,203)
# Tail has been in 2498 positions!
# HEAD = (270,202)  TAIL = (279,202)
# Tail has been in 2514 positions!
# HEAD = (284,202)  TAIL = (279,202)
# Tail has been in 2514 positions!
# HEAD = (284,188)  TAIL = (284,197)
# Tail has been in 2519 positions!
# HEAD = (284,207)  TAIL = (284,198)
# Tail has been in 2520 positions!
# HEAD = (284,203)  TAIL = (284,198)
# Tail has been in 2520 positions!
# HEAD = (284,218)  TAIL = (284,209)
# Tail has been in 2530 positions!
# HEAD = (284,217)  TAIL = (284,209)
# Tail has been in 2530 positions!
# HEAD = (296,217)  TAIL = (289,214)
# Tail has been in 2535 positions!
# HEAD = (295,217)  TAIL = (289,214)
# Tail has been in 2535 positions!
# HEAD = (295,203)  TAIL = (293,211)
# Tail has been in 2539 positions!
# HEAD = (295,216)  TAIL = (293,211)
# Tail has been in 2539 positions!
# HEAD = (291,216)  TAIL = (293,211)
# Tail has been in 2539 positions!
# HEAD = (306,216)  TAIL = (297,215)
# Tail has been in 2543 positions!
# HEAD = (305,216)  TAIL = (297,215)
# Tail has been in 2543 positions!
# HEAD = (322,216)  TAIL = (313,216)
# Tail has been in 2559 positions!
# HEAD = (313,216)  TAIL = (313,216)
# Tail has been in 2559 positions!
# HEAD = (313,206)  TAIL = (313,215)
# Tail has been in 2560 positions!
# HEAD = (304,206)  TAIL = (309,211)
# Tail has been in 2564 positions!
# HEAD = (304,208)  TAIL = (309,211)
# Tail has been in 2564 positions!
# HEAD = (287,208)  TAIL = (296,208)
# Tail has been in 2575 positions!
# HEAD = (287,212)  TAIL = (294,210)
# Tail has been in 2577 positions!
# HEAD = (287,205)  TAIL = (293,209)
# Tail has been in 2578 positions!
# HEAD = (290,205)  TAIL = (293,209)
# Tail has been in 2578 positions!
